# %%
import numpy as np
import tensorflow as tf
import random
import collections
from collections import Counter
import jieba

from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams['font.sans-serif']=['SimHei']#用来正常显示中文标签  
mpl.rcParams['font.family'] = 'STSong'
mpl.rcParams['font.size'] = 20

# %%
training_file = 'renti.txt'

# %%
#中文字
def get_ch_lable(txt_file):  
    labels= ""
    with open(txt_file, 'rb') as f:
        for label in f: 
            #labels =label.decode('utf-8')
            labels =labels+label.decode('utf8')
           
    return  labels
   
#分词
def fenci(training_data):
    seg_list = jieba.cut(training_data)  # 默认是精确模式  
    training_ci = " ".join(seg_list)
    training_ci = training_ci.split()
    #以空格将字符串分开
    training_ci = np.array(training_ci)
    training_ci = np.reshape(training_ci, [-1, ])
    return training_ci


def build_dataset(words, n_words):

  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
training_data =get_ch_lable(training_file)
print("总字数",len(training_data))
training_ci =fenci(training_data)
#print(training_ci)
print("总词数",len(training_ci))    
training_label, count, dictionary, words = build_dataset(training_ci, 350)

words_size = len(dictionary)
print("字典词数",words_size)
#print(training_label)#将文本转为词向量 
#print(words)#每个编号对应的词
#print(dictionary)#每个词对应的编号
#print(count)#每个词对应的个数
####################################################
# Out:
# 总字数 1542
# 总词数 961
# 字典词数 350

# %%
print('Sample data', training_label[:10], [words[i] for i in training_label[:10]])
data_index = 0
def generate_batch(data,batch_size, num_skips, skip_window):

  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window

  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  if data_index + span > len(data):
    data_index = 0

  buffer.extend(data[data_index:data_index + span])
  data_index += span

  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)

      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]

    if data_index == len(data):
      #print(data_index,len(data),span,len(data[:span]))
      #buffer[:] = data[:span]
      buffer = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1

  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels
# Out:
# Sample data [29, 286, 47, 26, 25, 331, 8, 10, 117, 148] ['人体', '阴阳', '与', '电能', '阴', '应该', '是', '身体', '里', '内在']

# %%
batch, labels = generate_batch(training_label,batch_size=8, num_skips=2, skip_window=1)

for i in range(8):# 取第一个字，后一个是标签，再取其前一个字当标签，
    print(batch[i], words[batch[i]], '->', labels[i, 0], words[labels[i, 0]])
# Out:
# 286 阴阳 -> 29 人体
# 286 阴阳 -> 47 与
# 47 与 -> 286 阴阳
# 47 与 -> 26 电能
# 26 电能 -> 47 与
# 26 电能 -> 25 阴
# 25 阴 -> 26 电能
# 25 阴 -> 331 应该

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window =np.int32( words_size/2 ) # Only pick dev samples in the head of the distribution.
print("valid_window",valid_window)
valid_examples = np.random.choice(valid_window, valid_size, replace=False)#0-words_size/2,中的数取16个。不能重复。
num_sampled = 64    # Number of negative examples to sample.
# Out:
# valid_window 175

# %%
tf.reset_default_graph()

train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
# Ops and variables pinned to the CPU because of missing GPU implementation
with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(tf.random_uniform([words_size, embedding_size], -1.0, 1.0))#94个，每个128个向量
    
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable( tf.truncated_normal([words_size, embedding_size],
                            stddev=1.0 / tf.sqrt(np.float32(embedding_size))))
                            
    nce_biases = tf.Variable(tf.zeros([words_size]))


# Compute the average NCE loss for the batch.
# tf.nce_loss automatically draws a new sample of the negative labels each
# time we evaluate the loss.
loss = tf.reduce_mean(
tf.nn.nce_loss(weights=nce_weights, biases=nce_biases,
                 labels=train_labels, inputs=embed,
                 num_sampled=num_sampled, num_classes=words_size))


# Construct the SGD optimizer using a learning rate of 1.0.
optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# Compute the cosine similarity between minibatch examples and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
print("________________________",similarity.shape)
# Out:
# W1202 23:55:10.391560 140017963583232 deprecation.py:323] From /home/lx/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1202 23:55:10.526457 140017963583232 deprecation.py:506] From <ipython-input-13-d43026ef8e9b>:28: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ________________________ (16, 350)

# %%
#Begin training.
num_steps = 100001
with tf.Session() as sess:
    sess.run( tf.global_variables_initializer() )
    print('Initialized')
    
    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(training_label, batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = sess.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        
#通过打印测试可以看到  embed的值在逐渐的被调节      
#        emv = sess.run(embed,feed_dict = {train_inputs: [37,18]})
#        print("emv-------------------",emv[0])

        if step % 2000 == 0:
          if step > 0:
            average_loss /= 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print('Average loss at step ', step, ': ', average_loss)
          average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        
        if step % 10000 == 0:
          sim = similarity.eval(session=sess)
          #print(valid_size)
          for i in range(valid_size):
            valid_word = words[valid_examples[i]]
            #print("valid_word",valid_word)#16
            top_k = 8  # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]  #argsort函数返回的是数组值从小到大的索引值
            #print("nearest",nearest,top_k)
            log_str = 'Nearest to %s:' % valid_word

            for k in range(top_k):
              close_word = words[nearest[k]]
              log_str = '%s,%s' % (log_str, close_word)
            print(log_str)
        
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  103.50071716308594
# Nearest to 舒服:,几次,太高时,不了,不会,也,了,起来,有神
# Nearest to 越:,眼部,UNK,修道,或,着,很,加速,4.0
# Nearest to 了:,从而,舒服,着,道家,大,另外,时候,内在
# Nearest to 输出:,烧毁,原理,有,看,支撑,糖类,这,或
# Nearest to 快速:,减小,和,杀伤力,电能,阴是,UNK,升,增加
# Nearest to 所有:,高时,更大,剃须刀,换上,恢复,与,短时间,放电
# Nearest to 完:,平板,运动会,累,人体,时间,转化成,但,比
# Nearest to 按住:,是,发动机,神经,阳是,整体,基因,多,运动
# Nearest to 更换:,更高,一部分,坏,当,理解,电量,快速,因为
# Nearest to 其:,死,让,电,配有,只要,整体,快速,而
# Nearest to 适量:,修道,电池,更新,个,不,就是,不会,基因
# Nearest to 长寿:,第一,坏,出生,换上,次数,不同,。,糖类
# Nearest to 所:,眼部,但,市面上,剃须刀,放电,累,某些,升
# Nearest to 对应:,起来,电池,更新,对,低时,随着,速度,成
# Nearest to 最:,成,友好,会练,第二,高手,）,时间,影响
# Nearest to 搏击:,着,要,使用,没电,大量,变压器,相当于,加大
# Average loss at step  2000 :  3.54556643858552
# Average loss at step  4000 :  2.653488976657391
# Average loss at step  6000 :  2.6284692468643187
# Average loss at step  8000 :  2.630242616742849
# Average loss at step  10000 :  2.617422237366438
# Nearest to 舒服:,几次,太高时,也,不会,有神,不了,多,了
# Nearest to 越:,眼部,着,加速,很,4.0,细胞分裂,阴阳,或
# Nearest to 了:,阴阳,舒服,从而,累,端粒,大,另外,太盛
# Nearest to 输出:,糖类,工作,支撑,烧毁,看,原理,阴阳,大
# Nearest to 快速:,和,减小,阴是,更换,电能,加速,阴阳,杀伤力
# Nearest to 所有:,高时,更大,剃须刀,提供,换上,肢体,恢复,放电
# Nearest to 完:,运动会,平板,累,转化成,但,时候,为什么,时间
# Nearest to 按住:,整体,发动机,是,阴阳,神经,基因,阳是,不会
# Nearest to 更换:,一部分,更高,坏,通过,配有,阴阳,快速,因为
# Nearest to 其:,死,阴阳,配有,快速,只要,电,寿命,而
# Nearest to 适量:,电池,修道,更新,个,阴阳,影响,速度,不会
# Nearest to 长寿:,第一,出生,不同,换上,坏,运动,阴阳,站
# Nearest to 所:,眼部,但,市面上,某些,升,剃须刀,累,阴阳
# Nearest to 对应:,阴阳,更新,对,起来,用电量,器官,低时,随着
# Nearest to 最:,成,友好,会练,第二,时间,阴阳,延长,）
# Nearest to 搏击:,着,变压器,大量,要,加大,相当于,糖,用电量
# Average loss at step  12000 :  2.611149060487747
# Average loss at step  14000 :  2.6124458585679533
# Average loss at step  16000 :  2.601117343276739
# Average loss at step  18000 :  2.590819024503231
# Average loss at step  20000 :  2.5981751114726066
# Nearest to 舒服:,几次,太高时,有神,也,了,多,不会,不了
# Nearest to 越:,着,眼部,加速,很,4.0,细胞分裂,。,或
# Nearest to 了:,舒服,累,从而,端粒,太盛,另外,大,几次
# Nearest to 输出:,糖类,工作,支撑,烧毁,看,在,原理,影响
# Nearest to 快速:,加速,和,减小,阴是,更换,电能,寿命,增加
# Nearest to 所有:,高时,更大,剃须刀,提供,肢体,恢复,换上,累
# Nearest to 完:,运动会,平板,累,为什么,转化成,但,时候,对
# Nearest to 按住:,整体,发动机,是,神经,走,基因,不会,然后
# Nearest to 更换:,一部分,更高,通过,坏,配有,因为,疲惫,快速
# Nearest to 其:,死,配有,快速,只要,增加,寿命,整体,精神
# Nearest to 适量:,电池,更新,修道,速度,个,影响,过程,电流
# Nearest to 长寿:,第一,出生,运动,不同,换上,坏,才,站
# Nearest to 所:,眼部,但,市面上,某些,的,升,剃须刀,得
# Nearest to 对应:,更新,对,用电量,起来,器官,低时,随着,成
# Nearest to 最:,友好,成,会练,第二,延长,时间,）,配有
# Nearest to 搏击:,着,变压器,大量,加大,用电量,糖,相当于,放尽
# Average loss at step  22000 :  2.604675631418824
# Average loss at step  24000 :  2.6024403521567585
# Average loss at step  26000 :  2.59419297516346
# Average loss at step  28000 :  2.589908627778292
# Average loss at step  30000 :  2.584222070455551
# Nearest to 舒服:,几次,太高时,了,有神,也,多,不会,第二
# Nearest to 越:,着,加速,眼部,负荷,很,4.0,细胞分裂,的
# Nearest to 了:,累,舒服,从而,端粒,太盛,另外,几次,大
# Nearest to 输出:,糖类,工作,支撑,影响,烧毁,在,高能,看
# Nearest to 快速:,加速,和,减小,电能,阴是,更换,寿命,放电
# Nearest to 所有:,高时,更大,提供,剃须刀,肢体,之类,累,恢复
# Nearest to 完:,运动会,平板,为什么,累,时候,对,转化成,但
# Nearest to 按住:,整体,发动机,是,走,神经,不会,然后,基因
# Nearest to 更换:,通过,更高,一部分,配有,坏,因为,疲惫,快速
# Nearest to 其:,死,配有,快速,舒服,功能,只要,寿命,没有
# Nearest to 适量:,电池,更新,修道,过程,速度,影响,个,不会
# Nearest to 长寿:,出生,第一,运动,不同,换上,这,坏,才
# Nearest to 所:,眼部,市面上,但,某些,的,升,得,剃须刀
# Nearest to 对应:,更新,用电量,对,起来,器官,会,低时,成
# Nearest to 最:,友好,成,会练,第二,延长,时间,）,配有
# Nearest to 搏击:,着,变压器,放尽,用电量,加大,大量,糖,相当于
# Average loss at step  32000 :  2.5803437765538693
# Average loss at step  34000 :  2.580341372281313
# Average loss at step  36000 :  2.5860434348583223
# Average loss at step  38000 :  2.578350883260369
# Average loss at step  40000 :  2.575885890305042
# Nearest to 舒服:,阴阳,几次,了,太高时,有神,多,总结,也
# Nearest to 越:,阴阳,着,加速,。,负荷,眼部,很,的
# Nearest to 了:,阴阳,累,舒服,从而,电流,就,端粒,几次
# Nearest to 输出:,阴阳,糖类,工作,影响,在,支撑,UNK,高能
# Nearest to 快速:,阴阳,加速,和,寿命,减小,阴是,更换,电能
# Nearest to 所有:,高时,阴阳,更大,提供,肢体,剃须刀,累,之类
# Nearest to 完:,阴阳,运动会,平板,为什么,累,多,时候,对
# Nearest to 按住:,阴阳,整体,走,发动机,是,神经,然后,不会
# Nearest to 更换:,阴阳,通过,更高,一部分,运动,坏,配有,疲惫
# Nearest to 其:,阴阳,死,配有,快速,功能,舒服,自己,再用
# Nearest to 适量:,阴阳,电池,更新,过程,速度,修道,影响,个
# Nearest to 长寿:,阴阳,运动,第一,出生,不同,换上,这,才
# Nearest to 所:,阴阳,眼部,市面上,但,某些,得,的,提供
# Nearest to 对应:,阴阳,用电量,更新,对,起来,会,器官,低时
# Nearest to 最:,友好,成,阴阳,会练,第二,延长,时间,）
# Nearest to 搏击:,阴阳,着,变压器,放尽,用电量,糖,加大,大量
# Average loss at step  42000 :  2.569550695121288
# Average loss at step  44000 :  2.5792190161943434
# Average loss at step  46000 :  2.5706122558861972
# Average loss at step  48000 :  2.5742473782226445
# Average loss at step  50000 :  2.5720381603091953
# Nearest to 舒服:,几次,了,太高时,有神,多,总结,也,不会
# Nearest to 越:,着,加速,负荷,。,的,更,眼部,得
# Nearest to 了:,累,舒服,从而,几次,电流,端粒,体都会,它
# Nearest to 输出:,工作,糖类,影响,高能,在,支撑,UNK,寿命
# Nearest to 快速:,加速,和,寿命,阴是,减小,加转,保养,放电
# Nearest to 所有:,高时,更大,提供,肢体,剃须刀,就,累,之类
# Nearest to 完:,运动会,为什么,平板,多,累,时候,对,做功
# Nearest to 按住:,整体,走,不会,然后,发动机,神经,是,基因
# Nearest to 更换:,通过,运动,更高,一部分,配有,坏,疲惫,因为
# Nearest to 其:,死,功能,配有,快速,舒服,自己,得,再用
# Nearest to 适量:,电池,更新,过程,速度,影响,输出,修道,个
# Nearest to 长寿:,运动,第一,不同,出生,这,换上,才,汽车
# Nearest to 所:,眼部,的,市面上,得,某些,但,升,提供
# Nearest to 对应:,用电量,更新,对,器官,起来,会,低时,UNK
# Nearest to 最:,友好,成,会练,第二,延长,时间,配有,）
# Nearest to 搏击:,着,变压器,放尽,用电量,糖,相当于,加大,大量
# Average loss at step  52000 :  2.587775923103094
# Average loss at step  54000 :  2.579098485216498
# Average loss at step  56000 :  2.5655139861479404
# Average loss at step  58000 :  2.5841737273037433
# Average loss at step  60000 :  2.5709264801740646
# Nearest to 舒服:,了,几次,有神,太高时,总结,多,简单,第二
# Nearest to 越:,负荷,着,加速,更,小时,的,跑,眼部
# Nearest to 了:,累,舒服,体都会,从而,电流,就,几次,举个
# Nearest to 输出:,工作,糖类,影响,高能,在,寿命,UNK,支撑
# Nearest to 快速:,加速,寿命,和,加转,量,放电,阴是,减小
# Nearest to 所有:,高时,更大,提供,肢体,更好,之类,累,剃须刀
# Nearest to 完:,为什么,运动会,多,平板,时候,对,累,挺类
# Nearest to 按住:,整体,走,然后,不会,神经,发动机,是,灵敏
# Nearest to 更换:,通过,运动,配有,一部分,更高,坏,疲惫,因为
# Nearest to 其:,死,功能,快速,舒服,配有,自己,得,再用
# Nearest to 适量:,过程,更新,电池,速度,输出,影响,个,修道
# Nearest to 长寿:,运动,这,不同,第一,出生,才,换上,汽车
# Nearest to 所:,眼部,的,得,市面上,某些,但,升,提供
# Nearest to 对应:,用电量,更新,器官,对,起来,会,低时,加大
# Nearest to 最:,友好,会练,成,第二,延长,时间,配有,为阳来
# Nearest to 搏击:,着,变压器,放尽,用电量,糖,不足,空挡,相当于
# Average loss at step  62000 :  2.592578527122736
# Average loss at step  64000 :  2.574208594635129
# Average loss at step  66000 :  2.5680754439234734
# Average loss at step  68000 :  2.5679201986044644
# Average loss at step  70000 :  2.587850684851408
# Nearest to 舒服:,了,几次,有神,太高时,简单,总结,多,第二
# Nearest to 越:,负荷,小时,的,。,加速,着,更,过
# Nearest to 了:,累,舒服,就,体都会,从而,电流,它,几次
# Nearest to 输出:,工作,糖类,影响,高能,寿命,在,放电,适量
# Nearest to 快速:,加速,寿命,量,和,加转,保养,道家,放电
# Nearest to 所有:,高时,更大,提供,肢体,之类,累,更好,太盛
# Nearest to 完:,为什么,运动会,多,平板,时候,对,累,挺类
# Nearest to 按住:,整体,走,然后,不会,是,神经,发动机,也
# Nearest to 更换:,通过,运动,一部分,更高,配有,坏,疲惫,长寿
# Nearest to 其:,死,功能,快速,舒服,得,物质,自己,再用
# Nearest to 适量:,过程,更新,速度,输出,电池,影响,个,体内
# Nearest to 长寿:,运动,这,不同,才,第一,换上,出生,汽车
# Nearest to 所:,眼部,的,得,市面上,某些,提供,升,但
# Nearest to 对应:,用电量,更新,器官,对,起来,加大,会,低时
# Nearest to 最:,友好,会练,成,第二,延长,时间,配有,为什么
# Nearest to 搏击:,变压器,放尽,着,用电量,糖,空挡,不足,一天
# Average loss at step  72000 :  2.5678282242119312
# Average loss at step  74000 :  2.5665515501499176
# Average loss at step  76000 :  2.5636524650305508
# Average loss at step  78000 :  2.5679323024600746
# Average loss at step  80000 :  2.5756420946121215
# Nearest to 舒服:,了,有神,几次,简单,太高时,总结,就,多
# Nearest to 越:,小时,负荷,加速,更,得,过,着,所以
# Nearest to 了:,累,舒服,体都会,电流,就,排量,举个,从而
# Nearest to 输出:,工作,寿命,糖类,高能,影响,放电,在,UNK
# Nearest to 快速:,加速,寿命,量,和,加转,放电,保养,道家
# Nearest to 所有:,高时,更大,肢体,提供,更好,之类,累,太盛
# Nearest to 完:,为什么,运动会,多,时候,平板,对,累,通过
# Nearest to 按住:,整体,走,然后,不会,神经,发动机,是,也
# Nearest to 更换:,通过,运动,一部分,更高,配有,长寿,坏,疲惫
# Nearest to 其:,死,功能,舒服,快速,得,阴,再用,自己
# Nearest to 适量:,过程,更新,输出,速度,电池,影响,个,体内
# Nearest to 长寿:,运动,这,才,不同,第一,换上,出生,汽车
# Nearest to 所:,眼部,得,市面上,某些,的,有,升,但
# Nearest to 对应:,用电量,更新,器官,对,起来,加大,会,低时
# Nearest to 最:,友好,会练,成,第二,延长,配有,为什么,体都会
# Nearest to 搏击:,变压器,放尽,用电量,着,糖,空挡,不足,一天
# Average loss at step  82000 :  2.5648097971975803
# Average loss at step  84000 :  2.5559236162602903
# Average loss at step  86000 :  2.5628132801353933
# Average loss at step  88000 :  2.5666833139657976
# Average loss at step  90000 :  2.555980253137648
# Nearest to 舒服:,了,有神,几次,总结,太高时,简单,年轻,就
# Nearest to 越:,小时,负荷,更,。,得,加速,过,的
# Nearest to 了:,累,舒服,排量,能量,电流,体都会,就,它
# Nearest to 输出:,寿命,工作,高能,影响,UNK,在,糖类,放电
# Nearest to 快速:,加速,量,寿命,加转,保养,和,道家,放电
# Nearest to 所有:,高时,更大,肢体,提供,更好,之类,累,太盛
# Nearest to 完:,为什么,多,运动会,时候,对,平板,通过,身体
# Nearest to 按住:,整体,走,然后,不会,是,神经,发动机,也
# Nearest to 更换:,运动,通过,一部分,长寿,更高,配有,坏,因为
# Nearest to 其:,功能,死,舒服,得,快速,阴,自己,内
# Nearest to 适量:,过程,更新,输出,速度,影响,电池,个,体内
# Nearest to 长寿:,运动,这,才,不同,换上,第一,出生,汽车
# Nearest to 所:,眼部,得,市面上,某些,的,提供,有,升
# Nearest to 对应:,用电量,更新,对,器官,加大,起来,低时,成
# Nearest to 最:,友好,会练,成,第二,延长,为什么,配有,）
# Nearest to 搏击:,放尽,变压器,用电量,空挡,糖,着,不足,一天
# Average loss at step  92000 :  2.5799225367754697
# Average loss at step  94000 :  2.572267834812403
# Average loss at step  96000 :  2.564291641280055
# Average loss at step  98000 :  2.5660531190633775
# Average loss at step  100000 :  2.5632779901474714
# Nearest to 舒服:,了,有神,简单,总结,年轻,几次,太高时,人
# Nearest to 越:,小时,负荷,更,得,过,为什么,相当于,，
# Nearest to 了:,累,能量,就,舒服,它,体都会,排量,电流
# Nearest to 输出:,寿命,工作,高能,在,影响,放电,糖类,UNK
# Nearest to 快速:,加速,量,寿命,加转,保养,和,道家,其
# Nearest to 所有:,高时,更大,肢体,提供,更好,之类,累,太盛
# Nearest to 完:,为什么,多,运动会,时候,对,身体,平板,中
# Nearest to 按住:,整体,走,然后,不会,神经,灵敏,是,发动机
# Nearest to 更换:,运动,通过,长寿,一部分,配有,更高,坏,疲惫
# Nearest to 其:,功能,死,舒服,阴,得,快速,自己,再用
# Nearest to 适量:,过程,更新,输出,速度,电池,影响,体内,个
# Nearest to 长寿:,运动,这,才,不同,换上,第一,出生,汽车
# Nearest to 所:,眼部,得,市面上,的,某些,提供,有,升
# Nearest to 对应:,用电量,器官,更新,对,加大,起来,低时,成
# Nearest to 最:,友好,会练,成,第二,延长,配有,为什么,相当于
# Nearest to 搏击:,放尽,变压器,用电量,空挡,不足,着,糖,一天

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,xy=(x, y),xytext=(5, 2), textcoords='offset points',
                     ha='right',va='bottom')
    plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 80#输出100个词
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [words[i] for i in range(plot_only)]
      #print(labels)
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
# Out:
# /home/lx/.local/lib/python3.5/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['STSong'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
