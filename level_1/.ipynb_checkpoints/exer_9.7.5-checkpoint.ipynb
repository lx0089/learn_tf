# %%
import numpy as np
import tensorflow as tf
import random
import collections
from collections import Counter
import jieba

from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.sans-serif']=['SimHei']#用来正常显示中文标签  
mpl.rcParams['font.family'] = 'STSong'
mpl.rcParams['font.size'] = 20

# %%
training_file = 'renti.txt'
    
#中文字
def get_ch_lable(txt_file):  
    labels= ""
    with open(txt_file, 'rb') as f:
        for label in f: 
            #labels =label.decode('utf-8')
            labels =labels+label.decode('utf8')
           
    return  labels
   
#分词
def fenci(training_data):
    seg_list = jieba.cut(training_data)  # 默认是精确模式  
    training_ci = " ".join(seg_list)
    training_ci = training_ci.split()
    #以空格将字符串分开
    training_ci = np.array(training_ci)
    training_ci = np.reshape(training_ci, [-1, ])
    return training_ci


def build_dataset(words, n_words):

  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  
  dictionary = dict()
  vocab_freqs = []
  for word, nvocab in count:
    dictionary[word] = len(dictionary)
    vocab_freqs.append(nvocab)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  
  return data, count, dictionary, reversed_dictionary,vocab_freqs

    
training_data =get_ch_lable(training_file)
print("总字数",len(training_data))
training_ci =fenci(training_data)
#print(training_ci)
print("总词数",len(training_ci))    
training_label, count, dictionary, words,vocab_freqs = build_dataset(training_ci, 350)

words_size = len(dictionary)
print("字典词数",words_size)
#print(training_label)#将文本转为词向量 
#print(words)#每个编号对应的词
#print(dictionary)#每个词对应的编号
#print(count)#每个词对应的个数
####################################################
print('Sample data', training_label[:10], [words[i] for i in training_label[:10]])
data_index = 0
def generate_batch(data,batch_size, num_skips, skip_window):

  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window

  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  if data_index + span > len(data):
    data_index = 0

  buffer.extend(data[data_index:data_index + span])
  data_index += span

  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)

      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]

    if data_index == len(data):
      #print(data_index,len(data),span,len(data[:span]))
      #buffer[:] = data[:span]
      buffer = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1

  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(training_label,batch_size=8, num_skips=2, skip_window=1)

for i in range(8):# 取第一个字，后一个是标签，再取其前一个字当标签，
    print(batch[i], words[batch[i]], '->', labels[i, 0], words[labels[i, 0]])
# Out:
# Building prefix dict from the default dictionary ...
# WARNING: Logging before flag parsing goes to stderr.
# I1203 00:06:56.370113 139847838471936 __init__.py:111] Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# I1203 00:06:56.371708 139847838471936 __init__.py:131] Loading model from cache /tmp/jieba.cache
# 总字数 1542
# Loading model cost 0.771 seconds.
# I1203 00:06:57.143209 139847838471936 __init__.py:163] Loading model cost 0.771 seconds.
# Prefix dict has been built succesfully.
# I1203 00:06:57.144786 139847838471936 __init__.py:164] Prefix dict has been built succesfully.
# 总词数 961
# 字典词数 350
# Sample data [27, 289, 43, 25, 28, 209, 8, 9, 82, 135] ['人体', '阴阳', '与', '电能', '阴', '应该', '是', '身体', '里', '内在']
# 289 阴阳 -> 43 与
# 289 阴阳 -> 27 人体
# 43 与 -> 289 阴阳
# 43 与 -> 25 电能
# 25 电能 -> 43 与
# 25 电能 -> 28 阴
# 28 阴 -> 25 电能
# 28 阴 -> 209 应该

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window =np.int32( words_size/2 ) # Only pick dev samples in the head of the distribution.
print("valid_window",valid_window)
valid_examples = np.random.choice(valid_window, valid_size, replace=False)#0-words_size/2,中的数取16个。不能重复。
num_sampled = 64    # Number of negative examples to sample.

tf.reset_default_graph()

train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Ops and variables pinned to the CPU because of missing GPU implementation
# with tf.device('/cpu:0'):
#     # Look up embeddings for inputs.
#     embeddings = tf.Variable(tf.random_uniform([words_size, embedding_size], -1.0, 1.0))#94个，每个128个向量
    
#     embed = tf.nn.embedding_lookup(embeddings, train_inputs)

#     # Construct the variables for the NCE loss
#     nce_weights = tf.Variable( tf.truncated_normal([words_size, embedding_size],
#                             stddev=1.0 / tf.sqrt(np.float32(embedding_size))))
                            
#     nce_biases = tf.Variable(tf.zeros([words_size]))

embeddings = tf.Variable(tf.random_uniform([words_size, embedding_size], -1.0, 1.0))#94个，每个128个向量
    
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# Construct the variables for the NCE loss
nce_weights = tf.Variable( tf.truncated_normal([words_size, embedding_size],
                        stddev=1.0 / tf.sqrt(np.float32(embedding_size))))
                            
nce_biases = tf.Variable(tf.zeros([words_size]))

vocab_freqs[0] = 90
            
                
sampled = tf.nn.fixed_unigram_candidate_sampler(
          true_classes=tf.cast(train_labels,tf.int64),
          num_true=1,
          num_sampled=num_sampled,
          unique=True,
          range_max=words_size,
          unigrams=vocab_freqs)
          
loss = tf.reduce_mean(
tf.nn.sampled_softmax_loss(weights=nce_weights, biases=nce_biases,
                          labels=train_labels, inputs=embed,
                num_sampled=num_sampled, num_classes=words_size,sampled_values=sampled))



# Construct the SGD optimizer using a learning rate of 1.0.
optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# Compute the cosine similarity between minibatch examples and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
print("________________________",similarity.shape)
# Out:
# valid_window 175
# W1203 00:07:59.108594 139847838471936 deprecation.py:506] From <ipython-input-4-54b403250a72>:63: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ________________________ (16, 350)

# %%
#Begin training.
num_steps = 100001
with tf.Session() as sess:
    sess.run( tf.global_variables_initializer() )
    print('Initialized')
    
    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(training_label, batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = sess.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        
#通过打印测试可以看到  embed的值在逐渐的被调节      
#        emv = sess.run(embed,feed_dict = {train_inputs: [37,18]})
#        print("emv-------------------",emv[0])

        if step % 2000 == 0:
          if step > 0:
            average_loss /= 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print('Average loss at step ', step, ': ', average_loss)
          average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        
        if step % 10000 == 0:
          sim = similarity.eval(session=sess)
          #print(valid_size)
          for i in range(valid_size):
            valid_word = words[valid_examples[i]]
            #print("valid_word",valid_word)#16
            top_k = 8  # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]  #argsort函数返回的是数组值从小到大的索引值
            #print("nearest",nearest,top_k)
            log_str = 'Nearest to %s:' % valid_word

            for k in range(top_k):
              close_word = words[nearest[k]]
              log_str = '%s,%s' % (log_str, close_word)
            print(log_str)
        
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  4.8540544509887695
# Nearest to 保养:,支配,刺激,不会,也,事物,端粒,适量,小时
# Nearest to 灵敏:,电能,之类,所,加速,快速,内部,还会,换上
# Nearest to 分解:,精神,1,运动员,原理,）,可能,不能,大量
# Nearest to 更加:,短时间,为,有,4.0,时,桩,精神,原理
# Nearest to 南孚:,升,眼部,没有,暂时,就,反映,充电,做静
# Nearest to 放:,事后,瞬间,放尽,只要,比,只是,变压器,放空
# Nearest to 物质:,不了,举个,换上,了,大小,早,为阳,电流
# Nearest to 为什么:,成,电池,可能,能活,所以,等静,内在,做功
# Nearest to 内:,电,事物,高能,其,没电,消耗,转化,运动过度
# Nearest to 快速:,小时,所有,适量,整体,一个,与,说明书,从而
# Nearest to 我们:,时挂,第一,一个,单位,一直,遥控,器官,使用
# Nearest to 要:,如此,起来,太盛,但,不同,器官,成,活动
# Nearest to 当有:,再用,内部,这个,车,能量,时,挺类,运动员
# Nearest to 起来:,会,要,支配,原理,但,不能,没有,让
# Nearest to 个:,但是,人会,别人,站,静挺,疲惫,各个,身体
# Nearest to 一个:,我们,快速,为了,运转,状态,1,增大,但是
# Average loss at step  2000 :  1.741652377307415
# Average loss at step  4000 :  1.5083582576587795
# Average loss at step  6000 :  1.493058585356921
# Average loss at step  8000 :  1.4840461702337489
# Average loss at step  10000 :  1.4807935130726546
# Nearest to 保养:,刺激,也,里,支配,适量,事物,身体,电压
# Nearest to 灵敏:,电能,之类,加速,内部,还会,换上,UNK,使
# Nearest to 分解:,原理,1,运动员,精神,）,可能,不能,我
# Nearest to 更加:,短时间,QQ,为,时,4.0,原理,精神,桩
# Nearest to 南孚:,眼部,升,充电,没有,暂时,没电,性能,做静
# Nearest to 放:,事后,瞬间,只要,比,放尽,变压器,UNK,按住
# Nearest to 物质:,不了,为阳,举个,更新,转化成,早,了,换上
# Nearest to 为什么:,成,能活,等静,所以,不能,会练,可能,做静
# Nearest to 内:,其,电,事物,没电,高能,转化,消耗,或
# Nearest to 快速:,小时,与,所有,适量,整体,一个,从而,也
# Nearest to 我们:,第一,时挂,单位,然后,一个,一直,遥控,尤其
# Nearest to 要:,起来,太盛,但,如此,器官,成,不动,不同
# Nearest to 当有:,这个,时,再用,车,内部,能量,成,更高
# Nearest to 起来:,要,支配,原理,一些,所有,让,会,自然
# Nearest to 个:,但是,人会,别人,疲惫,静挺,站,所,各个
# Nearest to 一个:,状态,快速,为了,1,我们,运转,增大,升
# Average loss at step  12000 :  1.4731283059809357
# Average loss at step  14000 :  1.4710674836412072
# Average loss at step  16000 :  1.4669654924720525
# Average loss at step  18000 :  1.4653907321877777
# Average loss at step  20000 :  1.462891080523841
# Nearest to 保养:,刺激,里,也,支配,事物,适量,身体,电压
# Nearest to 灵敏:,之类,内部,让,UNK,电能,加速,还会,休息
# Nearest to 分解:,原理,1,运动员,精神,）,可能,化成,我
# Nearest to 更加:,短时间,QQ,精神,4.0,为,原理,桩,时
# Nearest to 南孚:,眼部,升,充电,没有,暂时,性能,没电,做静
# Nearest to 放:,事后,瞬间,只要,比,放尽,变压器,摸索,器官
# Nearest to 物质:,不了,为阳,更新,举个,转化成,运转,早,另
# Nearest to 为什么:,成,能活,不能,等静,会练,所以,可能,做静
# Nearest to 内:,其,事物,电,没电,转化,高能,或,消耗
# Nearest to 快速:,小时,与,所有,适量,整体,也,一个,充电
# Nearest to 我们:,第一,时挂,然后,单位,电流,尤其,时候,一直
# Nearest to 要:,太盛,起来,但,如此,成,器官,不动,不同
# Nearest to 当有:,这个,时,再用,内部,车,能量,这,成
# Nearest to 起来:,要,支配,一些,所有,原理,让,自然,没有
# Nearest to 个:,但是,人会,别人,疲惫,静挺,所,站,各个
# Nearest to 一个:,状态,1,快速,为了,运转,我们,增大,机器
# Average loss at step  22000 :  1.4589929683469236
# Average loss at step  24000 :  1.4603657319983467
# Average loss at step  26000 :  1.4608762041926384
# Average loss at step  28000 :  1.4609960682448
# Average loss at step  30000 :  1.456486544540152
# Nearest to 保养:,里,刺激,也,事物,适量,支配,身体,固定
# Nearest to 灵敏:,让,之类,内部,休息,UNK,还会,其,换上
# Nearest to 分解:,原理,1,运动员,化成,）,起来,可能,精神
# Nearest to 更加:,短时间,QQ,精神,4.0,原理,桩,工作,为
# Nearest to 南孚:,眼部,升,充电,没有,暂时,性能,没电,做静
# Nearest to 放:,事后,瞬间,比,只要,器官,摸索,变压器,配有
# Nearest to 物质:,不了,为阳,更新,转化成,运转,举个,量,早
# Nearest to 为什么:,成,不能,能活,等静,会练,所以,完,做静
# Nearest to 内:,其,事物,电,转化,没电,高能,或,消耗
# Nearest to 快速:,小时,与,所有,也,适量,充电,整体,一个
# Nearest to 我们:,第一,然后,时挂,单位,电流,时候,尤其,为阳
# Nearest to 要:,太盛,起来,但,如此,成,不动,器官,需要
# Nearest to 当有:,这个,时,再用,这,能量,成,内部,车
# Nearest to 起来:,一些,所有,要,支配,原理,分解,让,出
# Nearest to 个:,但是,人会,别人,疲惫,静挺,所,站,各个
# Nearest to 一个:,状态,1,快速,为了,运转,机器,增大,体都会
# Average loss at step  32000 :  1.4555812469581142
# Average loss at step  34000 :  1.4556360389254988
# Average loss at step  36000 :  1.4508568813800813
# Average loss at step  38000 :  1.4504626701809467
# Average loss at step  40000 :  1.451210737789981
# Nearest to 保养:,里,刺激,也,事物,适量,支配,身体,固定
# Nearest to 灵敏:,让,休息,内部,之类,其,UNK,拥有,还会
# Nearest to 分解:,原理,1,化成,运动员,起来,）,可能,理解
# Nearest to 更加:,QQ,短时间,精神,4.0,工作,桩,原理,分裂
# Nearest to 南孚:,眼部,升,充电,没有,暂时,性能,没电,做静
# Nearest to 放:,事后,瞬间,比,只要,器官,摸索,配有,精神
# Nearest to 物质:,不了,为阳,更新,转化成,运转,举个,量,所有
# Nearest to 为什么:,成,不能,能活,会练,等静,完,所以,做静
# Nearest to 内:,其,事物,电,转化,没电,高能,或,运动过度
# Nearest to 快速:,小时,与,所有,也,加速,充电,适量,整体
# Nearest to 我们:,第一,然后,电流,时挂,单位,时候,为阳,尤其
# Nearest to 要:,太盛,起来,但,如此,成,不动,器官,需要
# Nearest to 当有:,这个,时,再用,这,能量,内部,更高,成
# Nearest to 起来:,所有,一些,要,支配,分解,原理,出,事物
# Nearest to 个:,但是,别人,人会,疲惫,所,静挺,站,运动
# Nearest to 一个:,状态,1,机器,快速,为了,运转,体都会,另
# Average loss at step  42000 :  1.4470173315666617
# Average loss at step  44000 :  1.4469940509330481
# Average loss at step  46000 :  1.4497979002576322
# Average loss at step  48000 :  1.4522672691978513
# Average loss at step  50000 :  1.451286906518042
# Nearest to 保养:,里,刺激,也,事物,适量,支配,身体,固定
# Nearest to 灵敏:,让,休息,内部,之类,其,拥有,呢,从而
# Nearest to 分解:,原理,化成,起来,1,运动员,理解,）,我
# Nearest to 更加:,QQ,精神,短时间,工作,4.0,原理,分裂,桩
# Nearest to 南孚:,眼部,升,充电,没有,性能,暂时,没电,做静
# Nearest to 放:,事后,瞬间,比,只要,器官,摸索,配有,精神
# Nearest to 物质:,不了,为阳,更新,运转,转化成,多,量,举个
# Nearest to 为什么:,不能,成,能活,完,会练,等静,所以,感到
# Nearest to 内:,其,事物,电,转化,没电,高能,或,运动过度
# Nearest to 快速:,小时,与,加速,所有,也,充电,适量,整体
# Nearest to 我们:,第一,然后,单位,电流,时挂,时候,尤其,为阳
# Nearest to 要:,太盛,起来,但,如此,成,不动,需要,器官
# Nearest to 当有:,这个,时,再用,这,成,能量,更高,内部
# Nearest to 起来:,所有,一些,要,分解,支配,出,原理,事物
# Nearest to 个:,但是,别人,疲惫,人会,所,静挺,运动,各个
# Nearest to 一个:,状态,1,机器,体都会,快速,另,运转,为了
# Average loss at step  52000 :  1.44936589089036
# Average loss at step  54000 :  1.4497912553753705
# Average loss at step  56000 :  1.4465086421249433
# Average loss at step  58000 :  1.448228757455945
# Average loss at step  60000 :  1.446056846551597
# Nearest to 保养:,里,刺激,也,事物,适量,支配,固定,身体
# Nearest to 灵敏:,让,休息,其,内部,之类,拥有,呢,从而
# Nearest to 分解:,原理,化成,起来,1,理解,运动员,我,不动
# Nearest to 更加:,QQ,精神,短时间,工作,4.0,分裂,原理,高时
# Nearest to 南孚:,眼部,升,充电,没有,性能,暂时,做静,没电
# Nearest to 放:,瞬间,事后,比,只要,器官,摸索,配有,精神
# Nearest to 物质:,不了,为阳,更新,运转,转化成,量,多,所有
# Nearest to 为什么:,不能,成,完,能活,会练,等静,感到,觉得
# Nearest to 内:,其,事物,电,转化,没电,高能,或,运动过度
# Nearest to 快速:,加速,小时,与,所有,量,充电,也,道家
# Nearest to 我们:,第一,然后,电流,单位,时候,也,为阳,功能
# Nearest to 要:,太盛,起来,但,如此,不动,成,需要,人会
# Nearest to 当有:,这个,时,这,再用,能量,成,更高,早
# Nearest to 起来:,所有,一些,分解,要,出,支配,事物,原理
# Nearest to 个:,但是,别人,疲惫,人会,所,静挺,运动,各个
# Nearest to 一个:,状态,1,机器,体都会,电池,加转,快速,另
# Average loss at step  62000 :  1.4483075828962029
# Average loss at step  64000 :  1.4443114475719632
# Average loss at step  66000 :  1.444343115620315
# Average loss at step  68000 :  1.4441223974488675
# Average loss at step  70000 :  1.4460538455843925
# Nearest to 保养:,里,刺激,也,事物,适量,支配,固定,油箱
# Nearest to 灵敏:,让,休息,其,内部,拥有,呢,从而,之类
# Nearest to 分解:,原理,化成,起来,1,理解,不动,运动员,一些
# Nearest to 更加:,QQ,精神,工作,短时间,4.0,分裂,使,高时
# Nearest to 南孚:,眼部,升,充电,没有,性能,暂时,做静,没电
# Nearest to 放:,瞬间,事后,比,只要,器官,摸索,配有,精神
# Nearest to 物质:,不了,为阳,更新,运转,转化成,量,所有,多
# Nearest to 为什么:,不能,完,成,能活,会练,等静,觉得,感到
# Nearest to 内:,其,事物,电,转化,没电,或,高能,运动过度
# Nearest to 快速:,加速,小时,与,所有,量,也,充电,道家
# Nearest to 我们:,第一,然后,电流,单位,时候,工作,功能,为阳
# Nearest to 要:,太盛,起来,但,如此,不动,成,需要,人会
# Nearest to 当有:,这个,时,这,再用,能量,成,更高,早
# Nearest to 起来:,所有,一些,分解,出,要,事物,支配,原理
# Nearest to 个:,但是,别人,疲惫,所,人会,静挺,运动,自我
# Nearest to 一个:,状态,1,机器,体都会,电池,加转,另,运转
# Average loss at step  72000 :  1.4473789424709975
# Average loss at step  74000 :  1.4447292429693044
# Average loss at step  76000 :  1.442425092358142
# Average loss at step  78000 :  1.442069602289237
# Average loss at step  80000 :  1.441789904844016
# Nearest to 保养:,里,刺激,事物,也,适量,支配,固定,油箱
# Nearest to 灵敏:,让,其,休息,内部,呢,拥有,从而,轰
# Nearest to 分解:,化成,原理,起来,理解,一些,1,不动,运动员
# Nearest to 更加:,QQ,工作,精神,使,4.0,短时间,高时,分裂
# Nearest to 南孚:,眼部,升,充电,没有,性能,暂时,做静,没电
# Nearest to 放:,瞬间,事后,比,只要,器官,配有,提升,摸索
# Nearest to 物质:,不了,为阳,更新,运转,转化成,量,所有,体内
# Nearest to 为什么:,不能,完,成,会练,能活,觉得,感到,速度
# Nearest to 内:,其,事物,转化,电,没电,或,高能,运动过度
# Nearest to 快速:,加速,与,小时,量,所有,道家,充电,也
# Nearest to 我们:,第一,然后,电流,单位,时候,也,功能,工作
# Nearest to 要:,太盛,起来,但,如此,不动,成,需要,车
# Nearest to 当有:,这个,时,这,再用,能量,成,早,更高
# Nearest to 起来:,所有,一些,分解,出,事物,要,支配,之类
# Nearest to 个:,但是,别人,疲惫,所,人会,静挺,运动,当
# Nearest to 一个:,状态,机器,1,电池,体都会,加转,另,运转
# Average loss at step  82000 :  1.4426181951127945
# Average loss at step  84000 :  1.4389906119694933
# Average loss at step  86000 :  1.4414584007300437
# Average loss at step  88000 :  1.4413633753638715
# Average loss at step  90000 :  1.4401160906087607
# Nearest to 保养:,里,刺激,事物,适量,也,支配,固定,输出
# Nearest to 灵敏:,其,让,休息,呢,拥有,内部,从而,轰
# Nearest to 分解:,化成,起来,原理,理解,一些,不动,爆发力,它
# Nearest to 更加:,QQ,使,工作,4.0,精神,分裂,高时,单位
# Nearest to 南孚:,眼部,升,充电,没有,性能,暂时,肢体,做静
# Nearest to 放:,瞬间,事后,比,器官,只要,提升,配有,摸索
# Nearest to 物质:,不了,为阳,更新,运转,转化成,阴,量,所有
# Nearest to 为什么:,完,不能,会练,成,能活,觉得,速度,感到
# Nearest to 内:,其,事物,转化,电,没电,或,高能,运动过度
# Nearest to 快速:,加速,量,小时,与,所有,道家,充电,也
# Nearest to 我们:,第一,然后,电流,单位,时候,功能,工作,也
# Nearest to 要:,太盛,起来,如此,不动,但,需要,成,人会
# Nearest to 当有:,这个,时,这,再用,提升,早,更高,能量
# Nearest to 起来:,所有,分解,一些,出,事物,要,之类,4.0
# Nearest to 个:,但是,别人,疲惫,所,人会,静挺,运动,当
# Nearest to 一个:,机器,状态,加转,电池,1,体都会,对,另
# Average loss at step  92000 :  1.4364868808779865
# Average loss at step  94000 :  1.4457288903035224
# Average loss at step  96000 :  1.4423647930277512
# Average loss at step  98000 :  1.4407459193728864
# Average loss at step  100000 :  1.4401110043618828
# Nearest to 保养:,里,刺激,事物,适量,也,输出,固定,油箱
# Nearest to 灵敏:,其,让,休息,呢,拥有,从而,内部,轰
# Nearest to 分解:,化成,起来,原理,理解,转化,一些,不动,爆发力
# Nearest to 更加:,QQ,使,工作,4.0,高时,分裂,精神,单位
# Nearest to 南孚:,眼部,充电,升,没有,性能,肢体,暂时,做静
# Nearest to 放:,瞬间,事后,比,器官,只要,提升,配有,摸索
# Nearest to 物质:,为阳,不了,更新,运转,转化成,阴,量,所有
# Nearest to 为什么:,完,不能,会练,成,能活,觉得,速度,感到
# Nearest to 内:,其,事物,转化,电,没电,或,运动过度,高能
# Nearest to 快速:,加速,量,与,小时,所有,道家,充电,也
# Nearest to 我们:,第一,然后,电流,单位,时候,功能,工作,尤其
# Nearest to 要:,太盛,起来,不动,如此,需要,成,但,车
# Nearest to 当有:,这个,时,这,提升,早,再用,成,更高
# Nearest to 起来:,所有,分解,一些,出,事物,之类,要,寿命
# Nearest to 个:,但是,别人,疲惫,所,运动,人会,静挺,当
# Nearest to 一个:,状态,机器,电池,1,加转,体都会,对,另

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,xy=(x, y),xytext=(5, 2), textcoords='offset points',
                     ha='right',va='bottom')
    plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 80#输出100个词
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [words[i] for i in range(plot_only)]
      #print(labels)
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
# Out:
# /home/lx/.local/lib/python3.5/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['STSong'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
